# %%
import pandas as pd

# %%
# construct the file path

# name of raw data file
fname_raw = "raw_data/central_park_weather_raw.csv"


# import csv file as pandas dataframe
df = pd.read_csv(fname_raw)

df.head()
# Out:
#        STATION                        NAME        DATE  DASF  MDSF  PRCP  \
# 0  USW00023062  DENVER CENTRAL PARK, CO US  2005-01-01   NaN   NaN  0.00
# 1  USW00023062  DENVER CENTRAL PARK, CO US  2005-01-02   NaN   NaN  0.00
# 2  USW00023062  DENVER CENTRAL PARK, CO US  2005-01-03   NaN   NaN  0.00
# 3  USW00023062  DENVER CENTRAL PARK, CO US  2005-01-04   NaN   NaN  0.00
# 4  USW00023062  DENVER CENTRAL PARK, CO US  2005-01-05   NaN   NaN  0.08
#
#    SNOW  SNWD  TAVG  TMAX  TMIN  TOBS  WT01  WT03  WT04  WT05  WT06  WT11
# 0   0.0   0.0   NaN  58.0  21.0  21.0   NaN   NaN   NaN   NaN   NaN   NaN
# 1   0.0   0.0   NaN  45.0  19.0  20.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2   0.0   0.0   NaN  32.0  15.0  15.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3   0.0   0.0   NaN  42.0  15.0  24.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4   1.7   2.0   NaN  24.0   2.0   2.0   NaN   NaN   NaN   NaN   NaN   NaN

# %% [markdown]
# ### The index is currently the standard RangeIndex. We want to make it such that the date acts as the index for each data point.

# %%
# change the index of the dataframe to be DATE column
df.set_index("DATE", inplace=True)

# turn the index from string into a datetime object
df.index = pd.to_datetime(df.index)

df.head()
# Out:
#                 STATION                        NAME  DASF  MDSF  PRCP  SNOW  \
# DATE
# 2005-01-01  USW00023062  DENVER CENTRAL PARK, CO US   NaN   NaN  0.00   0.0
# 2005-01-02  USW00023062  DENVER CENTRAL PARK, CO US   NaN   NaN  0.00   0.0
# 2005-01-03  USW00023062  DENVER CENTRAL PARK, CO US   NaN   NaN  0.00   0.0
# 2005-01-04  USW00023062  DENVER CENTRAL PARK, CO US   NaN   NaN  0.00   0.0
# 2005-01-05  USW00023062  DENVER CENTRAL PARK, CO US   NaN   NaN  0.08   1.7
#
#             SNWD  TAVG  TMAX  TMIN  TOBS  WT01  WT03  WT04  WT05  WT06  WT11
# DATE
# 2005-01-01   0.0   NaN  58.0  21.0  21.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2005-01-02   0.0   NaN  45.0  19.0  20.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2005-01-03   0.0   NaN  32.0  15.0  15.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2005-01-04   0.0   NaN  42.0  15.0  24.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2005-01-05   2.0   NaN  24.0   2.0   2.0   NaN   NaN   NaN   NaN   NaN   NaN

# %% [markdown]
# ### We see that there are a lot of NaN values in the dataset. Let's see how many missing values there are in comparison to the number of observations.

# %%
# number of observations
total_observations = df.shape[0]
print(f'Number of observations: {total_observations}')

# number of NaN values for each column
nan_values = pd.Series(df.apply(pd.isnull).sum(),
                       name="NaN count")

print(f'NaN values in each column:')

# sort rows by number of NaN values
nan_values.sort_values()
# Out:
# Number of observations: 7337
# NaN values in each column:
# STATION       0
# NAME          0
# PRCP          0
# SNWD          2
# SNOW          4
# TMAX         17
# TMIN         20
# TOBS        805
# WT03       6773
# WT01       7124
# WT05       7292
# WT06       7293
# WT04       7328
# WT11       7334
# MDSF       7335
# DASF       7335
# TAVG       7337
# Name: NaN count, dtype: int64

# %% [markdown]
# ### There is a significant jump in NaN values between the TMIN and TOBS columns. Therefore, we will tolerate all columns containing NaNs values less than or equal to the WSF5 column. First we create a list of all the columns we will accept.

# %%
# all acceptable columns and their corresponding Nan value counts
acceptable_columns = nan_values[nan_values <= nan_values["TMIN"]]

# turn acceptable_columns into a list of the columns with low Nan counts
acceptable_columns = acceptable_columns.index.to_list()

acceptable_columns
# Out:
# ['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN']

# %% [markdown]
# ### Now that we know which columns are acceptable, we can remove all other columns.

# %%
# remove columns with too many NaN values
df = df[acceptable_columns].copy()

df
# Out:
#                 STATION                        NAME  PRCP  SNOW  SNWD  TMAX  \
# DATE
# 2005-01-01  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  58.0
# 2005-01-02  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  45.0
# 2005-01-03  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  32.0
# 2005-01-04  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  42.0
# 2005-01-05  USW00023062  DENVER CENTRAL PARK, CO US  0.08   1.7   2.0  24.0
# ...                 ...                         ...   ...   ...   ...   ...
# 2025-02-28  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  63.0
# 2025-03-03  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  65.0
# 2025-03-04  USW00023062  DENVER CENTRAL PARK, CO US  0.11   0.0   0.0  63.0
# 2025-03-05  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  45.0
# 2025-03-25  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  69.0
#
#             TMIN
# DATE
# 2005-01-01  21.0
# 2005-01-02  19.0
# 2005-01-03  15.0
# 2005-01-04  15.0
# 2005-01-05   2.0
# ...          ...
# 2025-02-28  26.0
# 2025-03-03  31.0
# 2025-03-04  34.0
# 2025-03-05  22.0
# 2025-03-25  40.0
#
# [7337 rows x 7 columns]

# %% [markdown]
# ### Let's check to make sure that no row is completely filled with NaN

# %%
# all rows whose values are exclusively NaN (aside from STATION and NAME)
nan_rows = df[df.iloc[:,2:].isnull().all(axis=1)]

nan_rows
# Out:
# Empty DataFrame
# Columns: [STATION, NAME, PRCP, SNOW, SNWD, TMAX, TMIN]
# Index: []

# %% [markdown]
# ### Next we will fill in the remaining NaN values. In this context, it makes sense since the weather typically doesn't change dramatically between days. We will fill NaN values using the most recent previous value.

# %%
# fill missing values using previous value
df = df.ffill()

# number of null values for each column
nan_values_ffill = pd.Series(df.apply(pd.isnull).sum(),
                       name="NaN count")
print(f'Null values in each column after ffill():')
nan_values_ffill
# Out:
# Null values in each column after ffill():
# STATION    0
# NAME       0
# PRCP       0
# SNOW       0
# SNWD       0
# TMAX       0
# TMIN       0
# Name: NaN count, dtype: int64

# %% [markdown]
# ### Now we create a target column. We want to predict the next day's high temperature, so we will create a column called TARGET which will be the next day's high.

# %%
df["TARGET"] = df["TMAX"].shift(-1)
df.head()
# Out:
#                 STATION                        NAME  PRCP  SNOW  SNWD  TMAX  \
# DATE
# 2005-01-01  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  58.0
# 2005-01-02  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  45.0
# 2005-01-03  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  32.0
# 2005-01-04  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  42.0
# 2005-01-05  USW00023062  DENVER CENTRAL PARK, CO US  0.08   1.7   2.0  24.0
#
#             TMIN  TARGET
# DATE
# 2005-01-01  21.0    45.0
# 2005-01-02  19.0    32.0
# 2005-01-03  15.0    42.0
# 2005-01-04  15.0    24.0
# 2005-01-05   2.0     6.0

# %% [markdown]
# ### Because the final row does not have a target, we will remove it from the data set.

# %%
df = df.iloc[:-1,:]
df.head()
# Out:
#                 STATION                        NAME  PRCP  SNOW  SNWD  TMAX  \
# DATE
# 2005-01-01  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  58.0
# 2005-01-02  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  45.0
# 2005-01-03  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  32.0
# 2005-01-04  USW00023062  DENVER CENTRAL PARK, CO US  0.00   0.0   0.0  42.0
# 2005-01-05  USW00023062  DENVER CENTRAL PARK, CO US  0.08   1.7   2.0  24.0
#
#             TMIN  TARGET
# DATE
# 2005-01-01  21.0    45.0
# 2005-01-02  19.0    32.0
# 2005-01-03  15.0    42.0
# 2005-01-04  15.0    24.0
# 2005-01-05   2.0     6.0

# %% [markdown]
# ### Now we can export the dataframe as a csv file.

# %%
# cleaned file name
fname_clean = "clean_data/central_park_weather_clean.csv"

df.to_csv(fname_clean, index=True)

# %%
import pandas as pd

# %%
# construct the file path

# name of raw data file
fname_raw = "raw_data/DEN_weather_raw.csv"


# import csv file as pandas dataframe
df = pd.read_csv(fname_raw)

df.head()
# Out:
#        STATION                                 NAME        DATE  AWND    FMTM  \
# 0  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  2005-01-01  9.40    10.0
# 1  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  2005-01-02  5.59   326.0
# 2  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  2005-01-03  4.92  1519.0
# 3  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  2005-01-04  8.50  1031.0
# 4  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  2005-01-05  4.70  2348.0
#
#      PGTM  PRCP  PSUN  SNOW  SNWD  ...  WT11  WT13  WT14  WT15  WT16  WT17  \
# 0  1048.0  0.00   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   325.0  0.00   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2  1523.0  0.00   NaN   NaN   NaN  ...   NaN   1.0   NaN   NaN   NaN   NaN
# 3  1031.0  0.02   NaN   NaN   NaN  ...   NaN   1.0   NaN   NaN   NaN   NaN
# 4    50.0  0.10   NaN   NaN   1.0  ...   NaN   1.0   NaN   NaN   NaN   NaN
#
#    WT18  WT19  WT21  WT22
# 0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   1.0
# 3   1.0   NaN   NaN   1.0
# 4   1.0   NaN   NaN   1.0
#
# [5 rows x 39 columns]

# %% [markdown]
# ### The index is currently the standard RangeIndex. We want to make it such that the date acts as the index for each data point.

# %%
# change the index of the dataframe to be DATE column
df.set_index("DATE", inplace=True)

# turn the index from string into a datetime object
df.index = pd.to_datetime(df.index)

df.head()
# Out:
#                 STATION                                 NAME  AWND    FMTM  \
# DATE
# 2005-01-01  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  9.40    10.0
# 2005-01-02  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  5.59   326.0
# 2005-01-03  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  4.92  1519.0
# 2005-01-04  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  8.50  1031.0
# 2005-01-05  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  4.70  2348.0
#
#               PGTM  PRCP  PSUN  SNOW  SNWD  TAVG  ...  WT11  WT13  WT14  WT15  \
# DATE                                              ...
# 2005-01-01  1048.0  0.00   NaN   NaN   NaN  32.0  ...   NaN   NaN   NaN   NaN
# 2005-01-02   325.0  0.00   NaN   NaN   NaN  27.0  ...   NaN   NaN   NaN   NaN
# 2005-01-03  1523.0  0.00   NaN   NaN   NaN  30.0  ...   NaN   1.0   NaN   NaN
# 2005-01-04  1031.0  0.02   NaN   NaN   NaN  16.0  ...   NaN   1.0   NaN   NaN
# 2005-01-05    50.0  0.10   NaN   NaN   1.0   2.0  ...   NaN   1.0   NaN   NaN
#
#             WT16  WT17  WT18  WT19  WT21  WT22
# DATE
# 2005-01-01   NaN   NaN   NaN   NaN   NaN   NaN
# 2005-01-02   NaN   NaN   NaN   NaN   NaN   NaN
# 2005-01-03   NaN   NaN   NaN   NaN   NaN   1.0
# 2005-01-04   NaN   NaN   1.0   NaN   NaN   1.0
# 2005-01-05   NaN   NaN   1.0   NaN   NaN   1.0
#
# [5 rows x 38 columns]

# %% [markdown]
# ### We see that there are a lot of NaN values in the dataset. Let's see how many missing values there are in comparison to the number of observations.

# %%
# number of observations
total_observations = df.shape[0]
print(f'Number of observations: {total_observations}')

# number of NaN values for each column
nan_values = pd.Series(df.apply(pd.isnull).sum(),
                       name="NaN count")

print(f'NaN values in each column:')

# sort rows by number of NaN values
nan_values.sort_values()
# Out:
# Number of observations: 7370
# NaN values in each column:
# STATION       0
# NAME          0
# PRCP        185
# TMIN        245
# TMAX        245
# WDF2        246
# WSF2        246
# AWND        247
# WSF5        258
# WDF5        258
# SNWD        418
# SNOW        428
# TAVG       3134
# FMTM       4846
# PGTM       4994
# WT01       5640
# TSUN       6273
# PSUN       6335
# WT03       6383
# WT08       6546
# WT16       6622
# WT13       6797
# WT02       6836
# WT18       6959
# WT05       7141
# WT22       7204
# WT07       7263
# WT09       7263
# WT06       7312
# WT11       7316
# WT14       7316
# WT04       7339
# WT10       7358
# WT15       7358
# WT17       7364
# WESD       7366
# WT19       7368
# WT21       7368
# Name: NaN count, dtype: int64

# %% [markdown]
# ### There is a significant jump in NaN values between the SNOW and TAVG columns. Therefore, we will tolerate all columns containing NaNs values less than or equal to the SNOW column. First we create a list of all the columns we will accept.

# %%
# all acceptable columns and their corresponding Nan value counts
acceptable_columns = nan_values[nan_values <= nan_values["SNOW"]]

# turn acceptable_columns into a list of the columns with low Nan counts
acceptable_columns = acceptable_columns.index.to_list()

acceptable_columns
# Out:
# ['STATION',
#  'NAME',
#  'AWND',
#  'PRCP',
#  'SNOW',
#  'SNWD',
#  'TMAX',
#  'TMIN',
#  'WDF2',
#  'WDF5',
#  'WSF2',
#  'WSF5']

# %% [markdown]
# ### Now that we know which columns are acceptable, we can remove all other columns.

# %%
# remove columns with too many NaN values
df = df[acceptable_columns].copy()

df
# Out:
#                 STATION                                 NAME   AWND  PRCP  \
# DATE
# 2005-01-01  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   9.40  0.00
# 2005-01-02  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   5.59  0.00
# 2005-01-03  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   4.92  0.00
# 2005-01-04  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   8.50  0.02
# 2005-01-05  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   4.70  0.10
# ...                 ...                                  ...    ...   ...
# 2025-04-02  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  10.51  0.00
# 2025-04-03  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   7.16  0.13
# 2025-04-04  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  11.63  0.00
# 2025-04-05  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US    NaN   NaN
# 2025-04-06  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US    NaN   NaN
#
#             SNOW  SNWD  TMAX  TMIN   WDF2   WDF5  WSF2  WSF5
# DATE
# 2005-01-01   NaN   NaN  43.0  20.0  160.0   20.0  16.1  17.0
# 2005-01-02   NaN   NaN  33.0  20.0  170.0  170.0  16.1  17.0
# 2005-01-03   NaN   NaN  41.0  18.0   60.0   60.0  13.0  14.1
# 2005-01-04   NaN   NaN  26.0   5.0   20.0   20.0  17.9  21.0
# 2005-01-05   NaN   1.0   6.0  -3.0  210.0   30.0  10.1  12.1
# ...          ...   ...   ...   ...    ...    ...   ...   ...
# 2025-04-02   0.0   0.0  51.0  28.0  300.0  290.0  29.1  36.9
# 2025-04-03   1.0   0.0  40.0  27.0  100.0  100.0  21.9  28.0
# 2025-04-04   0.1   1.2  38.0  27.0   30.0   30.0  25.1  32.0
# 2025-04-05   NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN
# 2025-04-06   NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN
#
# [7370 rows x 12 columns]

# %% [markdown]
# ### It looks like measuring devices for certain values such as SNOW and SNWD were not implemented before January 01, 2005. We can try to remove any data before these measuring devices were implemented. Let's find the when the first valid measurements were recorded for each column.

# %%
# create a series with acceptable columns and their corresponding first valid entries
first_valid_entry = pd.Series([df[col].first_valid_index() for col in acceptable_columns],
                              index=acceptable_columns,
                              name = 'First Valid Entry')

first_valid_entry.sort_values()
# Out:
# STATION   2005-01-01
# NAME      2005-01-01
# AWND      2005-01-01
# PRCP      2005-01-01
# TMAX      2005-01-01
# TMIN      2005-01-01
# WDF2      2005-01-01
# WDF5      2005-01-01
# WSF2      2005-01-01
# WSF5      2005-01-01
# SNWD      2005-01-05
# SNOW      2006-02-01
# Name: First Valid Entry, dtype: datetime64[ns]

# %% [markdown]
# ### The SNOW colum is the last column to receive a valid measurement value. It's first proper measurement doesn't come until February 1, 2006, which accounts for most of the NaN values in this column. Therefore, we will remove all datapoints occurring before this date.

# %%
# SNOW column's first valid index
t0 = first_valid_entry["SNOW"]

# remove data before t0
df = df[df.index >= t0]

df
# Out:
#                 STATION                                 NAME   AWND  PRCP  \
# DATE
# 2006-02-01  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   8.05  0.00
# 2006-02-02  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  12.30  0.00
# 2006-02-03  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  10.96  0.00
# 2006-02-04  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   9.40  0.00
# 2006-02-05  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  16.78  0.00
# ...                 ...                                  ...    ...   ...
# 2025-04-02  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  10.51  0.00
# 2025-04-03  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   7.16  0.13
# 2025-04-04  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  11.63  0.00
# 2025-04-05  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US    NaN   NaN
# 2025-04-06  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US    NaN   NaN
#
#             SNOW  SNWD  TMAX  TMIN   WDF2   WDF5  WSF2  WSF5
# DATE
# 2006-02-01   0.0   0.0  53.0  22.0   20.0   30.0  21.0  25.1
# 2006-02-02   0.0   0.0  47.0  23.0  310.0  310.0  25.9  30.0
# 2006-02-03   0.0   0.0  44.0  22.0  340.0  340.0  36.9  46.1
# 2006-02-04   0.0   0.0  53.0  16.0  140.0  140.0  21.0  23.9
# 2006-02-05   0.0   0.0  46.0  19.0   10.0   10.0  36.0  42.9
# ...          ...   ...   ...   ...    ...    ...   ...   ...
# 2025-04-02   0.0   0.0  51.0  28.0  300.0  290.0  29.1  36.9
# 2025-04-03   1.0   0.0  40.0  27.0  100.0  100.0  21.9  28.0
# 2025-04-04   0.1   1.2  38.0  27.0   30.0   30.0  25.1  32.0
# 2025-04-05   NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN
# 2025-04-06   NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN
#
# [6974 rows x 12 columns]

# %% [markdown]
# ### We notice that the data fore April 05, 2025 and April 06, 2025 have no meaning (all values are NaN). Given that these are the two most recent dates, it is reasonable that the data has not been updated yet. We will simply remove rows like these.

# %%
# all rows whose values are exclusively NaN (aside from STATION and NAME)
nan_rows = df[df.iloc[:,2:].isnull().all(axis=1)]

nan_rows
# Out:
#                 STATION                                 NAME  AWND  PRCP  \
# DATE
# 2025-04-05  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   NaN   NaN
# 2025-04-06  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   NaN   NaN
#
#             SNOW  SNWD  TMAX  TMIN  WDF2  WDF5  WSF2  WSF5
# DATE
# 2025-04-05   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2025-04-06   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
# drop rows with all NaN values
df = df.drop(nan_rows.index, axis='index')

df
# Out:
#                 STATION                                 NAME   AWND  PRCP  \
# DATE
# 2006-02-01  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   8.05  0.00
# 2006-02-02  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  12.30  0.00
# 2006-02-03  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  10.96  0.00
# 2006-02-04  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   9.40  0.00
# 2006-02-05  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  16.78  0.00
# ...                 ...                                  ...    ...   ...
# 2025-03-31  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   8.95  0.00
# 2025-04-01  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  10.51  0.08
# 2025-04-02  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  10.51  0.00
# 2025-04-03  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   7.16  0.13
# 2025-04-04  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  11.63  0.00
#
#             SNOW  SNWD  TMAX  TMIN   WDF2   WDF5  WSF2  WSF5
# DATE
# 2006-02-01   0.0   0.0  53.0  22.0   20.0   30.0  21.0  25.1
# 2006-02-02   0.0   0.0  47.0  23.0  310.0  310.0  25.9  30.0
# 2006-02-03   0.0   0.0  44.0  22.0  340.0  340.0  36.9  46.1
# 2006-02-04   0.0   0.0  53.0  16.0  140.0  140.0  21.0  23.9
# 2006-02-05   0.0   0.0  46.0  19.0   10.0   10.0  36.0  42.9
# ...          ...   ...   ...   ...    ...    ...   ...   ...
# 2025-03-31   0.0   0.0  62.0  31.0  150.0  170.0  21.9  30.0
# 2025-04-01   0.3   0.0  52.0  29.0   10.0  350.0  30.0  38.0
# 2025-04-02   0.0   0.0  51.0  28.0  300.0  290.0  29.1  36.9
# 2025-04-03   1.0   0.0  40.0  27.0  100.0  100.0  21.9  28.0
# 2025-04-04   0.1   1.2  38.0  27.0   30.0   30.0  25.1  32.0
#
# [6972 rows x 12 columns]

# %% [markdown]
# ### Now let's see how many missing values we have after removing all those columns and datapoints.

# %%
# number of NaN values for each column
nan_values = pd.Series(df.apply(pd.isnull).sum(),
                       name="NaN count")
print(f'Null values in each column:')

# sort rows by number of
nan_values.sort_values()
# Out:
# Null values in each column:
# STATION      0
# NAME         0
# SNWD        30
# SNOW        30
# PRCP       183
# TMAX       243
# TMIN       243
# WDF2       244
# WSF2       244
# AWND       245
# WDF5       256
# WSF5       256
# Name: NaN count, dtype: int64

# %% [markdown]
# ### Next we will fill in the remaining NaN values. In this context, it makes sense since the weather typically doesn't change dramatically between days. We will fill NaN values using the most recent previous value.

# %%
# fill missing values using previous value
df = df.ffill()

# number of null values for each column
nan_values_ffill = pd.Series(df.apply(pd.isnull).sum(),
                       name="NaN count")
print(f'Null values in each column after ffill():')
nan_values_ffill
# Out:
# Null values in each column after ffill():
# STATION    0
# NAME       0
# AWND       0
# PRCP       0
# SNOW       0
# SNWD       0
# TMAX       0
# TMIN       0
# WDF2       0
# WDF5       0
# WSF2       0
# WSF5       0
# Name: NaN count, dtype: int64

# %% [markdown]
# ### Now we create a target column. We want to predict the next day's high temperature, so we will create a column called TARGET which will be the next day's high.

# %%
df["TARGET"] = df["TMAX"].shift(-1)
df.head()
# Out:
#                 STATION                                 NAME   AWND  PRCP  \
# DATE
# 2006-02-01  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   8.05   0.0
# 2006-02-02  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  12.30   0.0
# 2006-02-03  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  10.96   0.0
# 2006-02-04  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   9.40   0.0
# 2006-02-05  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  16.78   0.0
#
#             SNOW  SNWD  TMAX  TMIN   WDF2   WDF5  WSF2  WSF5  TARGET
# DATE
# 2006-02-01   0.0   0.0  53.0  22.0   20.0   30.0  21.0  25.1    47.0
# 2006-02-02   0.0   0.0  47.0  23.0  310.0  310.0  25.9  30.0    44.0
# 2006-02-03   0.0   0.0  44.0  22.0  340.0  340.0  36.9  46.1    53.0
# 2006-02-04   0.0   0.0  53.0  16.0  140.0  140.0  21.0  23.9    46.0
# 2006-02-05   0.0   0.0  46.0  19.0   10.0   10.0  36.0  42.9    45.0

# %% [markdown]
# ### Because the final row does not have a target, we will remove it from the data set.

# %%
df = df.iloc[:-1,:]
df.head()
# Out:
#                 STATION                                 NAME   AWND  PRCP  \
# DATE
# 2006-02-01  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   8.05   0.0
# 2006-02-02  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  12.30   0.0
# 2006-02-03  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  10.96   0.0
# 2006-02-04  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US   9.40   0.0
# 2006-02-05  USW00003017  DENVER INTERNATIONAL AIRPORT, CO US  16.78   0.0
#
#             SNOW  SNWD  TMAX  TMIN   WDF2   WDF5  WSF2  WSF5  TARGET
# DATE
# 2006-02-01   0.0   0.0  53.0  22.0   20.0   30.0  21.0  25.1    47.0
# 2006-02-02   0.0   0.0  47.0  23.0  310.0  310.0  25.9  30.0    44.0
# 2006-02-03   0.0   0.0  44.0  22.0  340.0  340.0  36.9  46.1    53.0
# 2006-02-04   0.0   0.0  53.0  16.0  140.0  140.0  21.0  23.9    46.0
# 2006-02-05   0.0   0.0  46.0  19.0   10.0   10.0  36.0  42.9    45.0

# %% [markdown]
# ### Now we can export the dataframe as a csv file.

# %%
# cleaned file name
fname_clean = "clean_data/DEN_weather_clean.csv" # change 'raw' to 'clean

df.to_csv(fname_clean, index=True)
